# %% [markdown]
# # Introduction
#
# The Historic Center of Mexico City is one of the most important tourist places in the country.
# In that place different stages of the history of the city and the country converge, from
# Pre-Columbian age to modern Mexico.
#
# There are many activities and places to visit like museums, concerts, restaurants,
# colonial churches, including archaeological sites. So it is possible to lose yourself in a world
# of activities.This project offers a small guide to visit those beautiful places for tourists
# with little limited.

# %%
# !conda install -c conda-forge geopy --yes 
print("*******\n Instaled \n *******")
# !conda install -c conda-forge folium=0.5.0 --yes
print("*******\n Instaled \n *******")
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# *******
#  Instaled
#  *******
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# *******
#  Instaled
#  *******

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %% [markdown]
# ##### Make sure that you have created a Foursquare developer account and have your credentials handy

# %%
CLIENT_ID = 'UAH3W4RN0P23JN0E3ETSW1D4F30GL54VX2UU52MHEQCNQQUF' # your Foursquare ID
CLIENT_SECRET = 'VMQCZGUHM12ZIOEMR4CMXDASOKEZEASOKO4TKQX2EAOEMAEA' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: UAH3W4RN0P23JN0E3ETSW1D4F30GL54VX2UU52MHEQCNQQUF
# CLIENT_SECRET:VMQCZGUHM12ZIOEMR4CMXDASOKEZEASOKO4TKQX2EAOEMAEA

# %% [markdown]
# #### Let's again assume that you are staying at Zócalo of Mexico City. So let's start by converting the Zócalo address to its latitude and longitude coordinates.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>foursquare_agent</em>, as shown below.

# %%
address = 'Plaza de la constitución (Zócalo)'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 19.4328333 -99.13316022232087

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ## 1. Search for a specific venue category
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# #### Now, let's assume that you want to visit a museum. So, let's define a query to search for museums that is within 1000 meters from the Zócalo.

# %%
search_query = 'Museo'
radius = 300
print(search_query + ' ... ready!')
# Out:
# Museo ... ready!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=UAH3W4RN0P23JN0E3ETSW1D4F30GL54VX2UU52MHEQCNQQUF&client_secret=VMQCZGUHM12ZIOEMR4CMXDASOKEZEASOKO4TKQX2EAOEMAEA&ll=19.4328333,-99.13316022232087&v=20180604&query=Museo&radius=300&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eb8461b0de0d9001bad3f88'},
#  'response': {'venues': [{'id': '4cad0e4cf47ea1431fce9621',
#     'name': 'Museo Nacional de las Culturas',
#     'location': {'address': 'Moneda 13',
#      'crossStreet': 'Carmen',
#      'lat': 19.433381573268193,
#      'lng': -99.13035480418951,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 19.433381573268193,
#        'lng': -99.13035480418951}],
#      'distance': 300,
#      'postalCode': '06060',
#      'cc': 'MX',
#      'city': 'Cuauhtemoc',
#      'state': 'Distrito Federal',
#      'country': 'México',
#      'formattedAddress': ['Moneda 13 (Carmen)',
#       '06060 Cuauhtémoc, Distrito Federal',
#       'México']},
#     'categories': [{'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'shortName': 'History Museum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
# ...

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id  \
# 0  4cad0e4cf47ea1431fce9621
# 1  4ba69b67f964a5206c6239e3
# 2  4c01566658dbc9286f27ee6b
# 3  4f621c4ce4b071dd73b2f621
# 4  4b058701f964a520c47a22e3
#
#                                                 name  \
# 0                     Museo Nacional de las Culturas
# 1                 Museo Mexicano Del Diseño (MUMEDI)
# 2                     Museo Archivo de la Fotografía
# 3  Museo de Arte de la Secretaría de Hacienda y C...
# 4                             Museo del Templo Mayor
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...  v-1589134893    False
# 1  [{'id': '4bf58dd8d48988d181941735', 'name': 'M...  v-1589134893    False
# ...

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name             categories  \
# 0                      Museo Nacional de las Culturas         History Museum
# 1                  Museo Mexicano Del Diseño (MUMEDI)                 Museum
# 2                      Museo Archivo de la Fotografía                 Museum
# 3   Museo de Arte de la Secretaría de Hacienda y C...             Art Museum
# 4                              Museo del Templo Mayor         History Museum
# 5                              Museo De La Caricatura         History Museum
# 6             Museo del Antiguo Colegio del Arzobispo             Art Museum
# 7                               Museo A Benito Juárez            Art Gallery
# 8                                       Museo De SHCP             Art Museum
# 9                    Museo de la Gastronomía Mexicana                 Museum
# 10                                Museo Benito Juárez         History Museum
# ...

# %% [markdown]
# #### Let's visualize the Italian restaurants that are nearby

# %%
dataframe_filtered.name
# Out:
# 0                        Museo Nacional de las Culturas
# 1                    Museo Mexicano Del Diseño (MUMEDI)
# 2                        Museo Archivo de la Fotografía
# 3     Museo de Arte de la Secretaría de Hacienda y C...
# 4                                Museo del Templo Mayor
# 5                                Museo De La Caricatura
# 6               Museo del Antiguo Colegio del Arzobispo
# 7                                 Museo A Benito Juárez
# 8                                         Museo De SHCP
# 9                      Museo de la Gastronomía Mexicana
# 10                                  Museo Benito Juárez
# 11                                       Museo Nacional
# 12                               Museo Fundación Hérdez
# 13                  Museo Histórico De Palacio Nacional
# 14                          Museo De Sitio CCEMX • INAH
# 15                                museo de arquitectura
# 16                                     Museo De La SHCP
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=17) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Zócalo
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Zócalo',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Museum as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Exploring venues around from Zócalo

# %%
# type your answer here
# The correct answer is:
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 1000 # define radius
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=UAH3W4RN0P23JN0E3ETSW1D4F30GL54VX2UU52MHEQCNQQUF&client_secret=VMQCZGUHM12ZIOEMR4CMXDASOKEZEASOKO4TKQX2EAOEMAEA&v=20180604&ll=19.4328333,-99.13316022232087&radius=1000&limit=100'

# %% [markdown]
# <a id="item2"></a>

# %%
results = requests.get(url).json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                 name  categories        lat  \
# 0     Catedral Metropolitana de la Asunción de María      Church  19.433526
# 1                  Plaza de la Constitución (Zócalo)       Plaza  19.432745
# 2  Murales de Diego Rivera en la Secretaría de Ed...  Art Museum  19.432621
# 3                                         Mercaderes  Restaurant  19.433979
# 4                        Gran Hotel Ciudad de México       Hotel  19.432137
#
#          lng
# 0 -99.133204
# 1 -99.133658
# 2 -99.131642
# 3 -99.134825
# 4 -99.134468

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# ## 2. Explore a Given Venue
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# #### Let's again assume that you choice Major Temple Museum.

# %%
venue_id = '4b058701f964a520c47a22e3' # ID of Major Temple Museum
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4b058701f964a520c47a22e3?client_id=UAH3W4RN0P23JN0E3ETSW1D4F30GL54VX2UU52MHEQCNQQUF&client_secret=VMQCZGUHM12ZIOEMR4CMXDASOKEZEASOKO4TKQX2EAOEMAEA&v=20180604'

# %% [markdown]
# #### Send GET request for result

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4b058701f964a520c47a22e3',
#  'name': 'Museo del Templo Mayor',
#  'contact': {},
#  'location': {'address': 'Seminario 8',
#   'crossStreet': 'República de Guatemala',
#   'lat': 19.43483927659205,
#   'lng': -99.13164186445894,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 19.43483927659205,
#     'lng': -99.13164186445894}],
#   'postalCode': '06060',
#   'cc': 'MX',
#   'city': 'Cuauhtemoc',
#   'state': 'Distrito Federal',
#   'country': 'México',
#   'formattedAddress': ['Seminario 8 (República de Guatemala)',
# ...

# %% [markdown]
# ### B. Get the venue's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 9.0

# %% [markdown]
# ## 4. Explore a location
# > `https://api.foursquare.com/v2/venues/`**explore**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### So, you just finished your gourmet dish at Ecco, and are just curious about the popular spots around the restaurant. In order to explore the area, let's start by getting the latitude and longitude values of Ecco Restaurant.

# %%
latitudeTM = 19.435
longitudeTM = -99.131389

# %% [markdown]
# #### Define URL

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitudeTM, longitudeTM, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=UAH3W4RN0P23JN0E3ETSW1D4F30GL54VX2UU52MHEQCNQQUF&client_secret=VMQCZGUHM12ZIOEMR4CMXDASOKEZEASOKO4TKQX2EAOEMAEA&ll=19.435,-99.131389&v=20180604&radius=1000&limit=100'

# %% [markdown]
# #### Send GET request and examine results

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around Major Temple Museum.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 100 around Major Temple Museum.'

# %% [markdown]
# #### Get relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4b058701f964a520c47a22e3',
#   'name': 'Museo del Templo Mayor',
#   'location': {'address': 'Seminario 8',
#    'crossStreet': 'República de Guatemala',
#    'lat': 19.43483927659205,
#    'lng': -99.13164186445894,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 19.43483927659205,
#      'lng': -99.13164186445894}],
#    'distance': 32,
#    'postalCode': '06060',
#    'cc': 'MX',
#    'city': 'Cuauhtemoc',
#    'state': 'Distrito Federal',
#    'country': 'México',
#    'formattedAddress': ['Seminario 8 (República de Guatemala)',
#     '06060 Cuauhtemoc, Distrito Federal',
#     'México']},
#   'categories': [{'id': '4bf58dd8d48988d190941735',
#     'name': 'History Museum',
#     'pluralName': 'History Museums',
#     'shortName': 'History Museum',
# ...

# %% [markdown]
# #### Process JSON and convert it to a clean dataframe

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                                 name      categories  \
# 0                             Museo del Templo Mayor  History Museum
# 1                   Antiguo Colegio de San Ildefonso      Art Museum
# 2                        Galería de Palacio Nacional          Museum
# 3                                El Colegio Nacional      Non-Profit
# 4                     Museo Nacional de las Culturas  History Museum
# 5         Anfiteatro Simón Bolívar: Música de Cámara    Concert Hall
# 6     Catedral Metropolitana de la Asunción de María          Church
# 7  Murales de Diego Rivera en la Secretaría de Ed...      Art Museum
# 8                                 Casa San Ildefonso          Hostel
# ...

# %% [markdown]
# #### Let's visualize these items on the map around our location

# %%
venues_map = folium.Map(location=[latitudeTM, longitudeTM], zoom_start=16) # generate map centred around Ecco


# add Major Temple as a red circle mark
folium.features.CircleMarker(
    [latitudeTM, longitudeTM],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id="item5"></a>

# %% [markdown]
# ## 5. Explore Trending Venues
# > `https://api.foursquare.com/v2/venues/`**trending**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**

# %% [markdown]
# #### Now, instead of simply exploring the area around Ecco, you are interested in knowing the venues that are trending at the time you are done with your lunch, meaning the places with the highest foot traffic. So let's do that and get the trending venues around Ecco.

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitudeTM, longitudeTM, VERSION)
# send GET request and get trending venues
results = requests.get(url).json()

# %% [markdown]
# ### Check if any venues are trending at this time

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %% [markdown]
# Now, depending on when you run the above code, you might get different venues since the venues with the highest foot traffic are fetched live.

# %% [markdown]
# ### Visualize trending venues

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitudeTM, longitudeTM], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'
