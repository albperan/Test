# %%
import pandas as pd
print("Imported libraries")
# Out:
# Imported libraries

# %%
# !wget -q -O 'PostalCode.txt' https://raw.githubusercontent.com/albperan/Test/master/PostalCodes.txt
print('Data downloaded!')
# !wget -q -O 'Coorditantes.csv' http://cocl.us/Geospatial_data
# Out:
# Data downloaded!

# %%
column_names = ['PostalCode', 'Borough', 'Neighborhood']

# %%
df = pd.read_csv('PostalCode.txt',sep="\t", names = column_names)
df
# Out:
#     PostalCode        Borough  \
# 0         M1A   Not assigned
# 1         M1B    Scarborough
# 2         M1C    Scarborough
# 3         M1E    Scarborough
# 4         M1G    Scarborough
# ..         ...            ...
# 175       M9V      Etobicoke
# 176       M9W      Etobicoke
# 177       M9X   Not assigned
# 178       M9Y   Not assigned
# 179       M9Z   Not assigned
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                       Malvern, Rouge
# 2               Rouge Hill, Port Union, Highland Creek
# 3                    Guildwood, Morningside, West Hill
# 4                                               Woburn
# ..                                                 ...
# 175  South Steeles, Silverstone, Humbergate, Jamest...
# 176                                          Northwest
# 177                                                NaN
# ...

# %%
df = df[df.Borough != 'Not assigned']
df.reset_index(inplace = True, drop = True) 
df
# Out:
#     PostalCode       Borough  \
# 0         M1B   Scarborough
# 1         M1C   Scarborough
# 2         M1E   Scarborough
# 3         M1G   Scarborough
# 4         M1H   Scarborough
# ..         ...           ...
# 98        M9N          York
# 99        M9P     Etobicoke
# 100       M9R     Etobicoke
# 101       M9V     Etobicoke
# 102       M9W     Etobicoke
#
#                                           Neighborhood
# 0                                       Malvern, Rouge
# 1               Rouge Hill, Port Union, Highland Creek
# 2                    Guildwood, Morningside, West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# ..                                                 ...
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village, St. Phillips, Martin Grove ...
# 101  South Steeles, Silverstone, Humbergate, Jamest...
# ...

# %%
df.shape
# Out:
# (103, 3)

# %%
dfCoordinates = pd.read_csv('Coorditantes.csv')
dfCoordinates
Lat = dfCoordinates[['Latitude']]
Lon = dfCoordinates[['Longitude']]

# %%
df['Latitude'] = Lat 
df['Longitude'] = Lon
df
# Out:
#     PostalCode       Borough  \
# 0         M1B   Scarborough
# 1         M1C   Scarborough
# 2         M1E   Scarborough
# 3         M1G   Scarborough
# 4         M1H   Scarborough
# ..         ...           ...
# 98        M9N          York
# 99        M9P     Etobicoke
# 100       M9R     Etobicoke
# 101       M9V     Etobicoke
# 102       M9W     Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                       Malvern, Rouge  43.806686 -79.194353
# 1               Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2                    Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# ..                                                 ...        ...        ...
# 98                                              Weston  43.706876 -79.518188
# ...
